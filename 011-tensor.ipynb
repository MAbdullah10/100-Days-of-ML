# %%
# !pip install numpy
# Out:
# ...
#    ---------------------------------------- 0.0/12.6 MB ? eta -:--:--
#    ---------------------------------------- 0.1/12.6 MB 2.0 MB/s eta 0:00:07
#    ---------------------------------------- 0.1/12.6 MB 1.8 MB/s eta 0:00:07
#     --------------------------------------- 0.2/12.6 MB 2.0 MB/s eta 0:00:07
#     --------------------------------------- 0.3/12.6 MB 1.9 MB/s eta 0:00:07
#    - -------------------------------------- 0.4/12.6 MB 1.9 MB/s eta 0:00:07
#    - -------------------------------------- 0.5/12.6 MB 1.8 MB/s eta 0:00:07
#    - -------------------------------------- 0.5/12.6 MB 1.8 MB/s eta 0:00:07
#    - -------------------------------------- 0.6/12.6 MB 1.8 MB/s eta 0:00:07
#    -- ------------------------------------- 0.7/12.6 MB 1.8 MB/s eta 0:00:07
#    -- ------------------------------------- 0.8/12.6 MB 1.8 MB/s eta 0:00:07
#    -- ------------------------------------- 0.9/12.6 MB 1.8 MB/s eta 0:00:07
# ...

# %%
import numpy as np

# %%
# 1-D tensor
a=np.array(4)
a
# Out:
# array(4)

# %%
a.ndim
# Out:
# 0

# %%
a2 = np.array([1,2,3])
a2
# Out:
# array([1, 2, 3])

# %%
a2.ndim
# Out:
# 1

# %%
a3 = np.array([[1,2,3],[4,5,6]])
a3
# Out:
# array([[1, 2, 3],
#        [4, 5, 6]])

# %%
a3.ndim
# Out:
# 2
