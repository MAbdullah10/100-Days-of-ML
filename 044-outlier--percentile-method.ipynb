# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

# %%
df = pd.read_csv('./src/placement.csv')
df.head()
# Out:
#    cgpa  placement_exam_marks  placed  height
# 0  3.25                 41.97       0   54.26
# 1  2.93                 27.00       1   59.00
# 2  3.32                 23.88       1   59.60
# 3  3.76                 24.25       0   59.98
# 4  2.88                  8.91       0   60.27

# %%
plt.figure(figsize=(10,6))
sns.distplot(df['height'])
plt.show()
# Out:
# C:\Users\MuhammadAbdullah\AppData\Local\Temp\ipykernel_24088\1821973248.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['height'])

# %%
sns.boxplot(df['height'])
# Out:
# <Axes: ylabel='height'>

# %%
upper_limit = df['height'].quantile(0.99)
lower_limit = df['height'].quantile(0.01)
upper_limit, lower_limit
# Out:
# (np.float64(77.63669999999999), np.float64(51.0))

# %%
df[(df['height']>=upper_limit)|(df['height']<=lower_limit)]
# Out:
#      cgpa  placement_exam_marks  placed  height
# 7    1.28                 33.23       0    51.0
# 15   2.00                 31.77       1    51.0
# 16   2.00                 90.00       0    50.0
# 198  3.03                 27.41       0    78.3
# 199  2.43                 17.51       0    79.0

# %%
new_df = df[(df['height']<upper_limit)&(df['height']>lower_limit)]
new_df
# Out:
#      cgpa  placement_exam_marks  placed  height
# 0    3.25                 41.97       0   54.26
# 1    2.93                 27.00       1   59.00
# 2    3.32                 23.88       1   59.60
# 3    3.76                 24.25       0   59.98
# 4    2.88                  8.91       0   60.27
# ..    ...                   ...     ...     ...
# 193  2.38                 12.65       0   75.32
# 194  3.09                  1.16       1   75.85
# 195  3.19                  2.53       1   76.41
# 196  2.56                  2.50       0   77.00
# 197  3.08                 20.95       0   77.63
#
# [195 rows x 4 columns]

# %%
df.describe()
# Out:
#              cgpa  placement_exam_marks      placed      height
# count  200.000000            200.000000  200.000000  200.000000
# mean     2.914650             22.180250    0.515000   65.274900
# std      0.534712             21.369446    0.501029    5.185417
# min      1.000000              0.220000    0.000000   50.000000
# 25%      2.587500              6.607500    0.000000   63.022500
# 50%      2.970000             15.860000    1.000000   65.545000
# 75%      3.240000             31.447500    1.000000   69.170000
# max      4.000000             95.000000    1.000000   79.000000

# %%
new_df.describe()
# Out:
#              cgpa  placement_exam_marks      placed      height
# count  197.000000            197.000000  197.000000  197.000000
# mean     2.921168             21.833147    0.522843   65.216650
# std      0.533587             20.971504    0.500750    4.927432
# min      1.000000              0.220000    0.000000   51.000000
# 25%      2.590000              6.570000    0.000000   63.030000
# 50%      2.980000             15.560000    1.000000   65.440000
# 75%      3.240000             31.360000    1.000000   69.070000
# max      4.000000             95.000000    1.000000   77.630000

# %%
sns.distplot(new_df['height'])
# Out:
# C:\Users\MuhammadAbdullah\AppData\Local\Temp\ipykernel_24088\1969344740.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(new_df['height'])
# <Axes: xlabel='height', ylabel='Density'>

# %%
sns.boxplot(new_df['height'])
# Out:
# <Axes: ylabel='height'>

# %%
# capping -- winsurization
df['height']=np.where(df['height']>=upper_limit, upper_limit, np.where(df['height']<=lower_limit, lower_limit, df['height']))
df
# Out:
#      cgpa  placement_exam_marks  placed   height
# 0    3.25                 41.97       0  54.2600
# 1    2.93                 27.00       1  59.0000
# 2    3.32                 23.88       1  59.6000
# 3    3.76                 24.25       0  59.9800
# 4    2.88                  8.91       0  60.2700
# ..    ...                   ...     ...      ...
# 195  3.19                  2.53       1  76.4100
# 196  2.56                  2.50       0  77.0000
# 197  3.08                 20.95       0  77.6300
# 198  3.03                 27.41       0  77.6367
# 199  2.43                 17.51       0  77.6367
#
# [200 rows x 4 columns]

# %%
df['height'].describe()
# Out:
# count    200.000000
# mean      65.269767
# std        5.145551
# min       51.000000
# 25%       63.022500
# 50%       65.545000
# 75%       69.170000
# max       77.636700
# Name: height, dtype: float64

# %%
sns.boxplot(df['height'])
# Out:
# <Axes: ylabel='height'>
