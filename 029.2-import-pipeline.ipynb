# %%
import pickle
import numpy as np

# %%
pipe = pickle.load(open('./output/pipe.pkl','rb'))

# %%
test_input = np.array([2,'male',31.0,0,0,10.5,'C'],dtype=object).reshape(1,7)
test_input
# Out:
# array([[2, 'male', 31.0, 0, 0, 10.5, 'C']], dtype=object)

# %%
pipe.predict(test_input)
# Out:
# c:\Users\ABDULLAH\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but SimpleImputer was fitted with feature names
#   warnings.warn(
# c:\Users\ABDULLAH\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but SimpleImputer was fitted with feature names
#   warnings.warn(
# array([1])
