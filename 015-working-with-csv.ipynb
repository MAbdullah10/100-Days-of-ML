# %%
import pandas as pd

# %%
# !pip install requests
# Out:
# ...
#
#    ---------------------------------------- 0/5 [urllib3]
#    ---------------------------------------- 0/5 [urllib3]
#    ---------------------------------------- 0/5 [urllib3]
#    ---------------------------------------- 0/5 [urllib3]
#    ---------------------------------------- 0/5 [urllib3]
#    ---------------------------------------- 0/5 [urllib3]
#    ---------------------------------------- 0/5 [urllib3]
#    ---------------------------------------- 0/5 [urllib3]
#    ---------------------------------------- 0/5 [urllib3]
#    -------- ------------------------------- 1/5 [idna]
#    -------- ------------------------------- 1/5 [idna]
#    -------- ------------------------------- 1/5 [idna]
#    ---------------- ----------------------- 2/5 [charset_normalizer]
#    ---------------- ----------------------- 2/5 [charset_normalizer]
#    ---------------- ----------------------- 2/5 [charset_normalizer]
#    ---------------- ----------------------- 2/5 [charset_normalizer]
# ...

# %%
#opening a CSV from URL
import requests
from io import StringIO

url = "https://gist.githubusercontent.com/kevin336/acbb2271e66c10a5b73aacf82ca82784/raw/employees.csv"
headers = {"User-Agent": "Mozillla/5.0 (Macintosh;Intel Mac OS X 10.14; rv:66.0) Gecko/20100101 Firefox /66.0"}
req = requests.get(url, headers=headers)
data = StringIO(req.text)

pd.read_csv(data)
# Out:
#     EMPLOYEE_ID   FIRST_NAME    LAST_NAME     EMAIL  PHONE_NUMBER  HIRE_DATE  \
# 0           198       Donald     OConnell  DOCONNEL  650.507.9833  21-JUN-07
# 1           199      Douglas        Grant    DGRANT  650.507.9844  13-JAN-08
# 2           200     Jennifer       Whalen   JWHALEN  515.123.4444  17-SEP-03
# 3           201      Michael    Hartstein  MHARTSTE  515.123.5555  17-FEB-04
# 4           202          Pat          Fay      PFAY  603.123.6666  17-AUG-05
# 5           203        Susan       Mavris   SMAVRIS  515.123.7777  07-JUN-02
# 6           204      Hermann         Baer     HBAER  515.123.8888  07-JUN-02
# 7           205      Shelley      Higgins  SHIGGINS  515.123.8080  07-JUN-02
# 8           206      William        Gietz    WGIETZ  515.123.8181  07-JUN-02
# 9           100       Steven         King     SKING  515.123.4567  17-JUN-03
# 10          101        Neena      Kochhar  NKOCHHAR  515.123.4568  21-SEP-05
# ...

# %%
# Sep Parameter + name
pd.read_csv("./src/sample_5x20.tsv",sep='\t',names=['first','second','third','fourth','fifth'])
# Out:
#       first   second    third   fourth    fifth
# 0   Column1  Column2  Column3  Column4  Column5
# 1      R1C1     R1C2     R1C3     R1C4     R1C5
# 2      R2C1     R2C2     R2C3     R2C4     R2C5
# 3      R3C1     R3C2     R3C3     R3C4     R3C5
# 4      R4C1     R4C2     R4C3     R4C4     R4C5
# 5      R5C1     R5C2     R5C3     R5C4     R5C5
# 6      R6C1     R6C2     R6C3     R6C4     R6C5
# 7      R7C1     R7C2     R7C3     R7C4     R7C5
# 8      R8C1     R8C2     R8C3     R8C4     R8C5
# 9      R9C1     R9C2     R9C3     R9C4     R9C5
# 10    R10C1    R10C2    R10C3    R10C4    R10C5
# 11    R11C1    R11C2    R11C3    R11C4    R11C5
# 12    R12C1    R12C2    R12C3    R12C4    R12C5
# 13    R13C1    R13C2    R13C3    R13C4    R13C5
# 14    R14C1    R14C2    R14C3    R14C4    R14C5
# 15    R15C1    R15C2    R15C3    R15C4    R15C5
# 16    R16C1    R16C2    R16C3    R16C4    R16C5
# 17    R17C1    R17C2    R17C3    R17C4    R17C5
# 18    R18C1    R18C2    R18C3    R18C4    R18C5
# ...

# %%
df =pd.read_csv('./src/kashti.csv')
df
# Out:
#      Unnamed: 0  survived  pclass     sex   age  sibsp  parch     fare  \
# 0             0         0       3    male  22.0      1      0   7.2500
# 1             1         1       1  female  38.0      1      0  71.2833
# 2             2         1       3  female  26.0      0      0   7.9250
# 3             3         1       1  female  35.0      1      0  53.1000
# 4             4         0       3    male  35.0      0      0   8.0500
# ..          ...       ...     ...     ...   ...    ...    ...      ...
# 886         886         0       2    male  27.0      0      0  13.0000
# 887         887         1       1  female  19.0      0      0  30.0000
# 888         888         0       3  female   NaN      1      2  23.4500
# 889         889         1       1    male  26.0      0      0  30.0000
# 890         890         0       3    male  32.0      0      0   7.7500
#
#     embarked   class    who  adult_male deck  embark_town alive  alone
# ...

# %%
# index column
df =pd.read_csv('./src/kashti.csv',index_col='Unnamed: 0')
df
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
#use_cols parameter
pd.read_csv('./src/kashti.csv',usecols=['survived','age','sex'])
# Out:
#      survived     sex   age
# 0           0    male  22.0
# 1           1  female  38.0
# 2           1  female  26.0
# 3           1  female  35.0
# 4           0    male  35.0
# ..        ...     ...   ...
# 886         0    male  27.0
# 887         1  female  19.0
# 888         0  female   NaN
# 889         1    male  26.0
# 890         0    male  32.0
#
# [891 rows x 3 columns]

# %%
# skip rows
pd.read_csv('.\src\salary_Data.csv',skiprows=[1,5])
# Out:
# <>:2: SyntaxWarning: invalid escape sequence '\s'
# <>:2: SyntaxWarning: invalid escape sequence '\s'
# C:\Users\ABDULLAH\AppData\Local\Temp\ipykernel_10856\69844631.py:2: SyntaxWarning: invalid escape sequence '\s'
#   pd.read_csv('.\src\salary_Data.csv',skiprows=[1,5])
#     YearsExperience  Salary
# 0               1.3   46205
# 1               1.5   37731
# 2               2.0   43525
# 3               2.9   56642
# 4               3.0   60150
# 5               3.2   54445
# 6               3.2   64445
# 7               3.7   57189
# 8               3.9   63218
# 9               4.0   55794
# 10              4.0   56957
# 11              4.1   57081
# 12              4.5   61111
# 13              4.9   67938
# 14              5.1   66029
# 15              5.3   83088
# 16              5.9   81363
# 17              6.0   93940
# 18              6.8   91738
# 19              7.1   98273
# 20              7.9  101302
# 21              8.2  113812
# 22              8.7  109431
# ...

# %%
#nrows
pd.read_csv('.\src\salary_Data.csv',nrows=10)
# Out:
# <>:2: SyntaxWarning: invalid escape sequence '\s'
# <>:2: SyntaxWarning: invalid escape sequence '\s'
# C:\Users\ABDULLAH\AppData\Local\Temp\ipykernel_10856\3443574832.py:2: SyntaxWarning: invalid escape sequence '\s'
#   pd.read_csv('.\src\salary_Data.csv',nrows=10)
#    YearsExperience  Salary
# 0              1.1   39343
# 1              1.3   46205
# 2              1.5   37731
# 3              2.0   43525
# 4              2.2   39891
# 5              2.9   56642
# 6              3.0   60150
# 7              3.2   54445
# 8              3.2   64445
# 9              3.7   57189

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   survived     891 non-null    int64
#  1   pclass       891 non-null    int64
#  2   sex          891 non-null    str
#  3   age          714 non-null    float64
#  4   sibsp        891 non-null    int64
#  5   parch        891 non-null    int64
#  6   fare         891 non-null    float64
#  7   embarked     889 non-null    str
#  8   class        891 non-null    str
#  9   who          891 non-null    str
#  10  adult_male   891 non-null    bool
#  11  deck         203 non-null    str
#  12  embark_town  889 non-null    str
#  13  alive        891 non-null    str
#  14  alone        891 non-null    bool
# dtypes: bool(2), float64(2), int64(4), str(7)
# memory usage: 92.4 KB

# %%
df['sibsp'] = df['sibsp'].astype(float)

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   survived     891 non-null    int64
#  1   pclass       891 non-null    int64
#  2   sex          891 non-null    str
#  3   age          714 non-null    float64
#  4   sibsp        891 non-null    float64
#  5   parch        891 non-null    int64
#  6   fare         891 non-null    float64
#  7   embarked     889 non-null    str
#  8   class        891 non-null    str
#  9   who          891 non-null    str
#  10  adult_male   891 non-null    bool
#  11  deck         203 non-null    str
#  12  embark_town  889 non-null    str
#  13  alive        891 non-null    str
#  14  alone        891 non-null    bool
# dtypes: bool(2), float64(3), int64(3), str(7)
# memory usage: 92.4 KB

# %%
# date by default coming in string have to convert it into date
pd.read_csv('.\src\salary_data.csv').info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 30 entries, 0 to 29
# Data columns (total 3 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   YearsExperience  30 non-null     float64
#  1   Salary           30 non-null     int64
#  2   Date             30 non-null     str
# dtypes: float64(1), int64(1), str(1)
# memory usage: 852.0 bytes
# <>:2: SyntaxWarning: invalid escape sequence '\s'
# <>:2: SyntaxWarning: invalid escape sequence '\s'
# C:\Users\ABDULLAH\AppData\Local\Temp\ipykernel_10856\3014228855.py:2: SyntaxWarning: invalid escape sequence '\s'
#   pd.read_csv('.\src\salary_data.csv').info()

# %%
pd.read_csv('.\src\salary_data.csv',parse_dates=['Date']).info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 30 entries, 0 to 29
# Data columns (total 3 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   YearsExperience  30 non-null     float64
#  1   Salary           30 non-null     int64
#  2   Date             30 non-null     datetime64[us]
# dtypes: datetime64[us](1), float64(1), int64(1)
# memory usage: 852.0 bytes
# <>:1: SyntaxWarning: invalid escape sequence '\s'
# <>:1: SyntaxWarning: invalid escape sequence '\s'
# C:\Users\ABDULLAH\AppData\Local\Temp\ipykernel_10856\1458089086.py:1: SyntaxWarning: invalid escape sequence '\s'
#   pd.read_csv('.\src\salary_data.csv',parse_dates=['Date']).info()
# C:\Users\ABDULLAH\AppData\Local\Temp\ipykernel_10856\1458089086.py:1: UserWarning: Parsing dates in %d/%m/%Y format when dayfirst=False (the default) was specified. Pass `dayfirst=True` or specify a format to silence this warning.
# ...

# %%
# defining NaNs in data
pd.read_csv('.\src\salary_data.csv',na_values=['na','-','_','0'])
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\s'
# <>:1: SyntaxWarning: invalid escape sequence '\s'
# C:\Users\ABDULLAH\AppData\Local\Temp\ipykernel_10856\1108566133.py:1: SyntaxWarning: invalid escape sequence '\s'
#   pd.read_csv('.\src\salary_data.csv',na_values=['na','-','_','0'])
#     YearsExperience  Salary        Date  NA Values
# 0               1.1   39343  20/10/2022        NaN
# 1               1.3   46205  21/11/2022        1.0
# 2               1.5   37731  20/10/2023        2.0
# 3               2.0   43525  21/11/2023        3.0
# 4               2.2   39891  20/10/2024        NaN
# 5               2.9   56642  21/11/2024        NaN
# 6               3.0   60150  20/10/2025        NaN
# 7               3.2   54445  21/11/2025        NaN
# 8               3.2   64445  20/10/2026        NaN
# 9               3.7   57189  21/11/2026        NaN
# 10              3.9   63218  20/10/2027        NaN
# 11              4.0   55794  21/11/2027        3.0
# ...

# %%
# loading huge dataset in chunks
df = pd.read_csv('.\src\kashti.csv',chunksize=100)
# Out:
# <>:2: SyntaxWarning: invalid escape sequence '\s'
# <>:2: SyntaxWarning: invalid escape sequence '\s'
# C:\Users\ABDULLAH\AppData\Local\Temp\ipykernel_10856\3659029193.py:2: SyntaxWarning: invalid escape sequence '\s'
#   df = pd.read_csv('.\src\kashti.csv',chunksize=100)

# %%
for chunks in df:
    print(chunks.shape)
# Out:
# (100, 16)
# (100, 16)
# (100, 16)
# (100, 16)
# (100, 16)
# (100, 16)
# (100, 16)
# (100, 16)
# (91, 16)

# %%
#converters
def rename (name):
    if name == 'male':
        return 'M'
    else:
        return name

# %%
#converters
pd.read_csv('.\src\kashti.csv',converters={'sex':rename})
# Out:
# <>:2: SyntaxWarning: invalid escape sequence '\s'
# <>:2: SyntaxWarning: invalid escape sequence '\s'
# C:\Users\ABDULLAH\AppData\Local\Temp\ipykernel_10856\2074019808.py:2: SyntaxWarning: invalid escape sequence '\s'
#   pd.read_csv('.\src\kashti.csv',converters={'sex':rename})
#      Unnamed: 0  survived  pclass     sex   age  sibsp  parch     fare  \
# 0             0         0       3       M  22.0      1      0   7.2500
# 1             1         1       1  female  38.0      1      0  71.2833
# 2             2         1       3  female  26.0      0      0   7.9250
# 3             3         1       1  female  35.0      1      0  53.1000
# 4             4         0       3       M  35.0      0      0   8.0500
# ..          ...       ...     ...     ...   ...    ...    ...      ...
# 886         886         0       2       M  27.0      0      0  13.0000
# 887         887         1       1  female  19.0      0      0  30.0000
# ...
